# %%
import matplotlib.pyplot as plt
import numpy as np

x = [0.05,0.25,0.45,0.65,0.85]
x = np.asarray(x)
y = [[0,0,3.394001103050359e-05,0.0012472954053710068,0.9987187645835985],
                 [0,0,0,0.1,0.9],
                 [0.07,0.36,0.38,0.098,1-0.07-0.36-0.38-0.098]]
name = ["A-Jaccard", "B-Jaccard", "C-FTCTree"]
plt.bar(x, y[0],
        width = 0.025,
        color = 'c',
        align = 'center',
        label = name[0],
        alpha = 0.5
       )
plt.bar(x+0.025, y[1],
        width = 0.025,
        color = 'r',
        align = 'center',
        label = name[1],
        alpha = 0.5
       )
plt.bar(x+0.05, y[2],
        width = 0.025,
        color = 'b',
        align = 'center',
        label = name[2],
        alpha = 0.5
       )
# 图例
plt.legend(loc = 'upper left')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [0.1,0.3,0.5,0.7,0.9]
x = np.asarray(x)
y = [[0.9,0.1,0,0,0],
    [0.27,0.31,0.22,0.12,1-0.27-0.31-0.22-0.12]]
name = ["B-Jaccard-before", "B-Jaccard-now"]
plt.bar(x, y[0],
        width = 0.025,
        color = 'c',
        align = 'center',
        label = name[0],
        alpha = 0.5
       )
plt.bar(x+0.025, y[1],
        width = 0.025,
        color = 'r',
        align = 'center',
        label = name[1],
        alpha = 0.5
       )
# 图例
plt.legend(loc = 'upper right')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = [0.1,0.3,0.5,0.7,0.9]
x = np.asarray(x)
y = [[0.07,0.36,0.38,0.098,1-0.07-0.36-0.38-0.098],
    [0.13140723770735224, 0.3000636375206822, 0.3783208179542658, 0.13766916974248017, 0.05253913707521955]]
name = ["C-FTCTree-before", "C-FTCTree-now"]
plt.bar(x, y[0],
        width = 0.025,
        color = 'c',
        align = 'center',
        label = name[0],
        alpha = 0.5
       )
plt.bar(x+0.025, y[1],
        width = 0.025,
        color = 'r',
        align = 'center',
        label = name[1],
        alpha = 0.5
       )
# 图例
plt.legend(loc = 'upper right')
plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 4, 8, 16, 32, 64, 128]
y = [
    [-1,0.02,0.03 , 0.04,0.06280128558139184, 0.1,0.13 ,0.15],
    [0.8,0.78 ,0.76 ,0.75 , 0.6686799140844685,0.6 ,0.51 , 0.3],
    [-1.0, 0.04816548824010907, 0.2522105920053238, 0.22334526408249222, 0.3384616420653611, 0.44633119415139144, 0.6133872357080888, 0.8373833312362445]
    ,[0.34703238513733636, 0.2725313432118409, 0.22058929234249047, 0.1267658158052421, -0.353146016250106, -0.9204470633268756, -1.0753647799577781, -1.7869698941663692]
]
name = ["B-Jaccard-before-sc", "B-Jaccard-before-cp", "B-Jaccard-now-sc","B-Jaccard-now-cp"]

plt.plot(x, y[0],
        color = 'c',
        label = name[0]
       )
plt.plot(x, y[1],
        color = 'r',
        label = name[1]
       )

plt.plot(x, y[2],
        color = 'b',
        label = name[2]
       )
plt.plot(x, y[3],
        color = 'g',
        label = name[3]
       )
# 图例
plt.legend(loc = 'best')
plt.show()
